# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from mlp.data_providers import CIFAR100DataProvider
# %matplotlib inline

# %%
train_data = CIFAR100DataProvider('train',batch_size=50)
valid_data = CIFAR100DataProvider('valid',batch_size=50)

# %%
get_images = train_data.next()[0]
image = get_images[11].reshape((32,32,3),order='F')
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %%
#Experiments all epoch 60. batch size 50

#2. Regularization
err_l101_train = []
err_l101_valid = []
err_l201_train = []
err_l201_valid = []
err_l1001_train = []
err_l1001_valid = []
err_l2001_train = []
err_l2001_valid = []


acc_l101_train = []
acc_l101_valid = []
acc_l201_train = []
acc_l201_valid = []
acc_l101_train = []
acc_l1001_valid = []
acc_l2001_train = []
acc_l2001_valid = []

# %%
graph_l101 = tf.Graph()
graph_l201 = tf.Graph()
graph_l1001 = tf.Graph()
graph_l2001 = tf.Graph()

# %%
def plot_graph(err_train,acc_train,err_valid,acc_valid,name="Graph"):
    path='./graphs/'+name
    val_epoch=range(5,105,5)
    err_epoch=range(1,101,1)
    plt.grid()
    plt.plot(err_epoch,err_train,'-b+',label='Train Error')
    plt.plot(val_epoch,err_valid,'-ro',label='Validation Error')
    plt.xlabel('Epochs')
    plt.ylabel('Error')
    plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
    plt.savefig(path+'_error.png')
    #plt.show()
    plt.close()
    plt.grid()
    plt.plot(err_epoch,acc_train,'-b+',label='Train Accuracy')
    plt.plot(val_epoch,acc_valid,'-ro',label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
    plt.savefig(path+'_accuracy.png')
    #plt.show()
    plt.close()

# %%
def fully_connected_layer(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu):
    weights = tf.Variable(
        tf.truncated_normal(
            [input_dim, output_dim], stddev=2. / (input_dim + output_dim)**0.5), 
        'weights')
    biases = tf.Variable(tf.zeros([output_dim]), 'biases')
    outputs = nonlinearity(tf.matmul(inputs, weights) + biases)
    return weights,outputs

# %%
def run_graph(custom_graph=None):
    num_epochs=100
    err_train=[]
    err_valid=[]
    acc_train=[]
    acc_valid=[]
    if custom_graph=="None":
        print "ERROR: Computation Graph not found"
    with tf.Session(graph=custom_graph) as sess:
        sess.run(init)
        for e in range(num_epochs):
            running_error = 0.
            running_accuracy = 0.
            for input_batch, target_batch in train_data:
                _, batch_error, batch_acc = sess.run(
                    [train_step, error, accuracy], 
                    feed_dict={inputs: input_batch, targets: target_batch})
                running_error += batch_error
                running_accuracy += batch_acc
            running_error /= train_data.num_batches
            running_accuracy /= train_data.num_batches
            err_train.append(running_error)
            acc_train.append(running_accuracy)
            print('End of epoch {0:02d}: err(train)={1:.2f} acc(train)={2:.2f}'
                  .format(e + 1, running_error, running_accuracy))
            if (e + 1) % 5 == 0:
                valid_error = 0.
                valid_accuracy = 0.
                for input_batch, target_batch in valid_data:
                    batch_error, batch_acc = sess.run(
                        [error, accuracy], 
                        feed_dict={inputs: input_batch, targets: target_batch})
                    valid_error += batch_error
                    valid_accuracy += batch_acc
                valid_error /= valid_data.num_batches
                valid_accuracy /= valid_data.num_batches
                err_valid.append(valid_error)
                acc_valid.append(valid_accuracy)
                print('                 err(valid)={0:.2f} acc(valid)={1:.2f}'
                       .format(valid_error, valid_accuracy))
        return err_train,acc_train,err_valid,acc_valid

# %% [markdown]
# ## Begin regularization

# %%
#l1 Regularization beta = 0.01
#http://stackoverflow.com/questions/38286717/tensorflow-regularization-with-l2-loss-how-to-apply-to-all-weights-not-just
with graph_l101.as_default():
    with tf.name_scope('data'):
        inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
        targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
        num_hidden = 200
        beta = 0.01
    with tf.name_scope('fc-layer-3'):
        w1,hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], num_hidden)
        w2,hidden_2 = fully_connected_layer(hidden_1, num_hidden, num_hidden)
        w3,hidden_3 = fully_connected_layer(hidden_2, num_hidden, num_hidden)
    with tf.name_scope('output-layer'):
        w4,outputs = fully_connected_layer(hidden_3, num_hidden, train_data.num_classes, tf.identity)

    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets))+beta*(tf.reduce_mean(tf.abs(w1))+
                                                                                                tf.reduce_mean(tf.abs(w2))+
                                                                                                tf.reduce_mean(tf.abs(w3))+
                                                                                                tf.reduce_mean(tf.abs(w4))))
    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)),tf.float32))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer().minimize(error)
    init = tf.global_variables_initializer()
start = time.time()
err_l101_train,acc_l101_train,err_l101_valid,acc_l101_valid = run_graph(graph_l101)
print("Time taken: %f"%(time.time()-start))
# Out:
# End of epoch 01: err(train)=4.12 acc(train)=0.07
# End of epoch 02: err(train)=3.74 acc(train)=0.13
# End of epoch 03: err(train)=3.59 acc(train)=0.15
# End of epoch 04: err(train)=3.49 acc(train)=0.17
# End of epoch 05: err(train)=3.40 acc(train)=0.18
#                  err(valid)=3.47 acc(valid)=0.18
# End of epoch 06: err(train)=3.33 acc(train)=0.20
# End of epoch 07: err(train)=3.27 acc(train)=0.20
# End of epoch 08: err(train)=3.20 acc(train)=0.22
# End of epoch 09: err(train)=3.15 acc(train)=0.23
# End of epoch 10: err(train)=3.10 acc(train)=0.23
#                  err(valid)=3.38 acc(valid)=0.20
# End of epoch 11: err(train)=3.06 acc(train)=0.24
# End of epoch 12: err(train)=3.03 acc(train)=0.25
# End of epoch 13: err(train)=2.99 acc(train)=0.25
# End of epoch 14: err(train)=2.95 acc(train)=0.26
# End of epoch 15: err(train)=2.91 acc(train)=0.27
#                  err(valid)=3.39 acc(valid)=0.21
# End of epoch 16: err(train)=2.88 acc(train)=0.27
# End of epoch 17: err(train)=2.84 acc(train)=0.28
# End of epoch 18: err(train)=2.82 acc(train)=0.28
# End of epoch 19: err(train)=2.79 acc(train)=0.29
# End of epoch 20: err(train)=2.76 acc(train)=0.30
#                  err(valid)=3.53 acc(valid)=0.20
# End of epoch 21: err(train)=2.73 acc(train)=0.30
# End of epoch 22: err(train)=2.70 acc(train)=0.31
# End of epoch 23: err(train)=2.67 acc(train)=0.31
# End of epoch 24: err(train)=2.66 acc(train)=0.31
# End of epoch 25: err(train)=2.63 acc(train)=0.32
#                  err(valid)=3.65 acc(valid)=0.20
# End of epoch 26: err(train)=2.60 acc(train)=0.32
# End of epoch 27: err(train)=2.58 acc(train)=0.33
# End of epoch 28: err(train)=2.55 acc(train)=0.34
# End of epoch 29: err(train)=2.53 acc(train)=0.34
# End of epoch 30: err(train)=2.51 acc(train)=0.34
#                  err(valid)=3.80 acc(valid)=0.19
# End of epoch 31: err(train)=2.49 acc(train)=0.35
# End of epoch 32: err(train)=2.48 acc(train)=0.35
# End of epoch 33: err(train)=2.46 acc(train)=0.36
# End of epoch 34: err(train)=2.44 acc(train)=0.36
# End of epoch 35: err(train)=2.42 acc(train)=0.36
#                  err(valid)=3.94 acc(valid)=0.20
# End of epoch 36: err(train)=2.40 acc(train)=0.37
# End of epoch 37: err(train)=2.38 acc(train)=0.37
# End of epoch 38: err(train)=2.37 acc(train)=0.38
# End of epoch 39: err(train)=2.36 acc(train)=0.38
# End of epoch 40: err(train)=2.33 acc(train)=0.38
#                  err(valid)=4.07 acc(valid)=0.19
# End of epoch 41: err(train)=2.33 acc(train)=0.38
# End of epoch 42: err(train)=2.30 acc(train)=0.39
# End of epoch 43: err(train)=2.30 acc(train)=0.39
# End of epoch 44: err(train)=2.29 acc(train)=0.39
# End of epoch 45: err(train)=2.26 acc(train)=0.40
#                  err(valid)=4.25 acc(valid)=0.18
# End of epoch 46: err(train)=2.26 acc(train)=0.40
# End of epoch 47: err(train)=2.24 acc(train)=0.40
# End of epoch 48: err(train)=2.24 acc(train)=0.40
# End of epoch 49: err(train)=2.21 acc(train)=0.40
# End of epoch 50: err(train)=2.20 acc(train)=0.41
#                  err(valid)=4.48 acc(valid)=0.18
# End of epoch 51: err(train)=2.19 acc(train)=0.41
# End of epoch 52: err(train)=2.18 acc(train)=0.42
# End of epoch 53: err(train)=2.17 acc(train)=0.42
# End of epoch 54: err(train)=2.16 acc(train)=0.42
# End of epoch 55: err(train)=2.15 acc(train)=0.42
#                  err(valid)=4.59 acc(valid)=0.18
# End of epoch 56: err(train)=2.15 acc(train)=0.42
# End of epoch 57: err(train)=2.13 acc(train)=0.42
# End of epoch 58: err(train)=2.12 acc(train)=0.43
# End of epoch 59: err(train)=2.11 acc(train)=0.43
# End of epoch 60: err(train)=2.12 acc(train)=0.43
#                  err(valid)=4.72 acc(valid)=0.18
# End of epoch 61: err(train)=2.09 acc(train)=0.43
# End of epoch 62: err(train)=2.08 acc(train)=0.44
# End of epoch 63: err(train)=2.08 acc(train)=0.44
# End of epoch 64: err(train)=2.07 acc(train)=0.44
# End of epoch 65: err(train)=2.07 acc(train)=0.44
#                  err(valid)=4.85 acc(valid)=0.18
# End of epoch 66: err(train)=2.04 acc(train)=0.45
# End of epoch 67: err(train)=2.05 acc(train)=0.45
# End of epoch 68: err(train)=2.04 acc(train)=0.44
# End of epoch 69: err(train)=2.04 acc(train)=0.44
# End of epoch 70: err(train)=2.02 acc(train)=0.45
#                  err(valid)=5.09 acc(valid)=0.17
# End of epoch 71: err(train)=2.03 acc(train)=0.45
# End of epoch 72: err(train)=2.00 acc(train)=0.46
# End of epoch 73: err(train)=2.00 acc(train)=0.45
# End of epoch 74: err(train)=2.00 acc(train)=0.46
# End of epoch 75: err(train)=1.98 acc(train)=0.46
#                  err(valid)=5.09 acc(valid)=0.17
# End of epoch 76: err(train)=1.98 acc(train)=0.46
# End of epoch 77: err(train)=1.99 acc(train)=0.46
# End of epoch 78: err(train)=1.98 acc(train)=0.46
# End of epoch 79: err(train)=1.98 acc(train)=0.46
# End of epoch 80: err(train)=1.97 acc(train)=0.46
#                  err(valid)=5.38 acc(valid)=0.17
# End of epoch 81: err(train)=1.95 acc(train)=0.47
# End of epoch 82: err(train)=1.94 acc(train)=0.47
# End of epoch 83: err(train)=1.93 acc(train)=0.47
# End of epoch 84: err(train)=1.93 acc(train)=0.47
# End of epoch 85: err(train)=1.94 acc(train)=0.47
#                  err(valid)=5.42 acc(valid)=0.17
# End of epoch 86: err(train)=1.93 acc(train)=0.47
# End of epoch 87: err(train)=1.91 acc(train)=0.48
# End of epoch 88: err(train)=1.92 acc(train)=0.48
# End of epoch 89: err(train)=1.89 acc(train)=0.48
# End of epoch 90: err(train)=1.90 acc(train)=0.48
#                  err(valid)=5.62 acc(valid)=0.17
# End of epoch 91: err(train)=1.89 acc(train)=0.48
# End of epoch 92: err(train)=1.89 acc(train)=0.48
# End of epoch 93: err(train)=1.88 acc(train)=0.48
# End of epoch 94: err(train)=1.88 acc(train)=0.48
# End of epoch 95: err(train)=1.89 acc(train)=0.48
#                  err(valid)=5.69 acc(valid)=0.17
# End of epoch 96: err(train)=1.86 acc(train)=0.49
# End of epoch 97: err(train)=1.88 acc(train)=0.48
# End of epoch 98: err(train)=1.86 acc(train)=0.49
# End of epoch 99: err(train)=1.87 acc(train)=0.49
# End of epoch 100: err(train)=1.85 acc(train)=0.49
#                  err(valid)=5.87 acc(valid)=0.17
# Time taken: 4260.632625

# %%
#l1 Regularization beta = 0.001
#http://stackoverflow.com/questions/38286717/tensorflow-regularization-with-l2-loss-how-to-apply-to-all-weights-not-just
with graph_l1001.as_default():
    with tf.name_scope('data'):
        inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
        targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
        num_hidden = 200
        beta = 0.001
    with tf.name_scope('fc-layer-3'):
        w1,hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], num_hidden)
        w2,hidden_2 = fully_connected_layer(hidden_1, num_hidden, num_hidden)
        w3,hidden_3 = fully_connected_layer(hidden_2, num_hidden, num_hidden)
    with tf.name_scope('output-layer'):
        w4,outputs = fully_connected_layer(hidden_3, num_hidden, train_data.num_classes, tf.identity)

    with tf.name_scope('error'):
         error = tf.reduce_mean(tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets))+beta*(tf.reduce_mean(tf.abs(w1))+
                                                                                                tf.reduce_mean(tf.abs(w2))+
                                                                                                tf.reduce_mean(tf.abs(w3))+
                                                                                                tf.reduce_mean(tf.abs(w4))))
    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)),tf.float32))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer().minimize(error)
    init = tf.global_variables_initializer()
start = time.time()
err_l1001_train,acc_l1001_train,err_l1001_valid,acc_l1001_valid = run_graph(graph_l1001)
print("Time taken: %f"%(time.time()-start))
# Out:
# End of epoch 01: err(train)=1.90 acc(train)=0.31
# End of epoch 02: err(train)=1.71 acc(train)=0.38
# End of epoch 03: err(train)=1.63 acc(train)=0.42
# End of epoch 04: err(train)=1.57 acc(train)=0.43
# End of epoch 05: err(train)=1.53 acc(train)=0.45
#                  err(valid)=1.57 acc(valid)=0.44
# End of epoch 06: err(train)=1.49 acc(train)=0.47
# End of epoch 07: err(train)=1.46 acc(train)=0.48
# End of epoch 08: err(train)=1.43 acc(train)=0.49
# End of epoch 09: err(train)=1.41 acc(train)=0.50
# End of epoch 10: err(train)=1.38 acc(train)=0.50
#                  err(valid)=1.54 acc(valid)=0.46
# End of epoch 11: err(train)=1.36 acc(train)=0.51
# End of epoch 12: err(train)=1.34 acc(train)=0.52
# End of epoch 13: err(train)=1.31 acc(train)=0.53
# End of epoch 14: err(train)=1.30 acc(train)=0.54
# End of epoch 15: err(train)=1.27 acc(train)=0.55
#                  err(valid)=1.49 acc(valid)=0.49
# End of epoch 16: err(train)=1.26 acc(train)=0.55
# End of epoch 17: err(train)=1.24 acc(train)=0.56
# End of epoch 18: err(train)=1.21 acc(train)=0.56
# End of epoch 19: err(train)=1.19 acc(train)=0.57
# End of epoch 20: err(train)=1.18 acc(train)=0.57
#                  err(valid)=1.52 acc(valid)=0.48
# End of epoch 21: err(train)=1.16 acc(train)=0.58
# End of epoch 22: err(train)=1.14 acc(train)=0.59
# End of epoch 23: err(train)=1.13 acc(train)=0.59
# End of epoch 24: err(train)=1.11 acc(train)=0.60
# End of epoch 25: err(train)=1.09 acc(train)=0.61
#                  err(valid)=1.62 acc(valid)=0.48
# End of epoch 26: err(train)=1.08 acc(train)=0.61
# End of epoch 27: err(train)=1.06 acc(train)=0.62
# End of epoch 28: err(train)=1.05 acc(train)=0.62
# End of epoch 29: err(train)=1.03 acc(train)=0.63
# End of epoch 30: err(train)=1.02 acc(train)=0.63
#                  err(valid)=1.67 acc(valid)=0.47
# End of epoch 31: err(train)=1.00 acc(train)=0.63
# End of epoch 32: err(train)=0.99 acc(train)=0.64
# End of epoch 33: err(train)=0.98 acc(train)=0.65
# End of epoch 34: err(train)=0.96 acc(train)=0.65
# End of epoch 35: err(train)=0.94 acc(train)=0.66
#                  err(valid)=1.80 acc(valid)=0.47
# End of epoch 36: err(train)=0.94 acc(train)=0.66
# End of epoch 37: err(train)=0.93 acc(train)=0.66
# End of epoch 38: err(train)=0.91 acc(train)=0.67
# End of epoch 39: err(train)=0.91 acc(train)=0.67
# End of epoch 40: err(train)=0.88 acc(train)=0.68
#                  err(valid)=1.96 acc(valid)=0.46
# End of epoch 41: err(train)=0.88 acc(train)=0.68
# End of epoch 42: err(train)=0.85 acc(train)=0.69
# End of epoch 43: err(train)=0.85 acc(train)=0.69
# End of epoch 44: err(train)=0.84 acc(train)=0.70
# End of epoch 45: err(train)=0.83 acc(train)=0.69
#                  err(valid)=1.95 acc(valid)=0.47
# End of epoch 46: err(train)=0.82 acc(train)=0.70
# End of epoch 47: err(train)=0.79 acc(train)=0.71
# End of epoch 48: err(train)=0.81 acc(train)=0.71
# End of epoch 49: err(train)=0.79 acc(train)=0.71
# End of epoch 50: err(train)=0.77 acc(train)=0.72
#                  err(valid)=2.16 acc(valid)=0.46
# End of epoch 51: err(train)=0.77 acc(train)=0.72
# End of epoch 52: err(train)=0.76 acc(train)=0.72
# End of epoch 53: err(train)=0.75 acc(train)=0.73
# End of epoch 54: err(train)=0.75 acc(train)=0.72
# End of epoch 55: err(train)=0.74 acc(train)=0.73
#                  err(valid)=2.30 acc(valid)=0.45
# End of epoch 56: err(train)=0.74 acc(train)=0.73
# End of epoch 57: err(train)=0.72 acc(train)=0.74
# End of epoch 58: err(train)=0.71 acc(train)=0.74
# End of epoch 59: err(train)=0.71 acc(train)=0.74
# End of epoch 60: err(train)=0.71 acc(train)=0.74
#                  err(valid)=2.35 acc(valid)=0.45
# End of epoch 61: err(train)=0.68 acc(train)=0.75
# End of epoch 62: err(train)=0.69 acc(train)=0.75
# End of epoch 63: err(train)=0.69 acc(train)=0.75
# End of epoch 64: err(train)=0.67 acc(train)=0.76
# End of epoch 65: err(train)=0.68 acc(train)=0.75
#                  err(valid)=2.53 acc(valid)=0.45
# End of epoch 66: err(train)=0.65 acc(train)=0.76
# End of epoch 67: err(train)=0.66 acc(train)=0.76
# End of epoch 68: err(train)=0.64 acc(train)=0.77
# End of epoch 69: err(train)=0.65 acc(train)=0.76
# End of epoch 70: err(train)=0.64 acc(train)=0.76
#                  err(valid)=2.66 acc(valid)=0.45
# End of epoch 71: err(train)=0.64 acc(train)=0.77
# End of epoch 72: err(train)=0.62 acc(train)=0.77
# End of epoch 73: err(train)=0.62 acc(train)=0.77
# End of epoch 74: err(train)=0.61 acc(train)=0.78
# End of epoch 75: err(train)=0.62 acc(train)=0.77
#                  err(valid)=2.76 acc(valid)=0.45
# End of epoch 76: err(train)=0.60 acc(train)=0.78
# End of epoch 77: err(train)=0.60 acc(train)=0.78
# End of epoch 78: err(train)=0.60 acc(train)=0.78
# End of epoch 79: err(train)=0.60 acc(train)=0.78
# End of epoch 80: err(train)=0.59 acc(train)=0.78
#                  err(valid)=2.94 acc(valid)=0.45
# End of epoch 81: err(train)=0.58 acc(train)=0.79
# End of epoch 82: err(train)=0.58 acc(train)=0.79
# End of epoch 83: err(train)=0.57 acc(train)=0.79
# End of epoch 84: err(train)=0.57 acc(train)=0.79
# End of epoch 85: err(train)=0.57 acc(train)=0.79
#                  err(valid)=3.03 acc(valid)=0.44
# End of epoch 86: err(train)=0.57 acc(train)=0.79
# End of epoch 87: err(train)=0.55 acc(train)=0.80
# End of epoch 88: err(train)=0.56 acc(train)=0.80
# End of epoch 89: err(train)=0.55 acc(train)=0.80
# End of epoch 90: err(train)=0.53 acc(train)=0.80
#                  err(valid)=3.22 acc(valid)=0.44
# End of epoch 91: err(train)=0.56 acc(train)=0.80
# End of epoch 92: err(train)=0.55 acc(train)=0.80
# End of epoch 93: err(train)=0.53 acc(train)=0.80
# End of epoch 94: err(train)=0.53 acc(train)=0.81
# End of epoch 95: err(train)=0.52 acc(train)=0.81
#                  err(valid)=3.27 acc(valid)=0.45
# End of epoch 96: err(train)=0.53 acc(train)=0.81
# End of epoch 97: err(train)=0.51 acc(train)=0.81
# End of epoch 98: err(train)=0.51 acc(train)=0.81
# End of epoch 99: err(train)=0.53 acc(train)=0.81
# End of epoch 100: err(train)=0.50 acc(train)=0.82
#                  err(valid)=3.46 acc(valid)=0.45
# Time taken: 4206.445215

# %%
#l2 Regularization beta = 0.01
#http://stackoverflow.com/questions/38286717/tensorflow-regularization-with-l2-loss-how-to-apply-to-all-weights-not-just
with graph_l201.as_default():
    with tf.name_scope('data'):
        inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
        targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
        num_hidden = 200
        beta = 0.01
    with tf.name_scope('fc-layer-3'):
        w1,hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], num_hidden)
        w2,hidden_2 = fully_connected_layer(hidden_1, num_hidden, num_hidden)
        w3,hidden_3 = fully_connected_layer(hidden_2, num_hidden, num_hidden)
    with tf.name_scope('output-layer'):
        w4,outputs = fully_connected_layer(hidden_3, num_hidden, train_data.num_classes, tf.identity)

    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets)) +tf.reduce_mean(beta*(tf.nn.l2_loss(w1)+tf.nn.l2_loss(w2)+tf.nn.l2_loss(w3)+tf.nn.l2_loss(w4)))
    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)),tf.float32))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer().minimize(error)
    init = tf.global_variables_initializer()
start = time.time()
err_l201_train,acc_l201_train,err_l201_valid,acc_l201_valid = run_graph(graph_l201)
print("Time taken: %f"%(time.time()-start))
# Out:
# End of epoch 01: err(train)=5.28 acc(train)=0.06
# End of epoch 02: err(train)=4.23 acc(train)=0.09
# End of epoch 03: err(train)=4.15 acc(train)=0.10
# End of epoch 04: err(train)=4.10 acc(train)=0.11
# End of epoch 05: err(train)=4.09 acc(train)=0.11
#                  err(valid)=4.13 acc(valid)=0.11
# End of epoch 06: err(train)=4.06 acc(train)=0.12
# End of epoch 07: err(train)=4.05 acc(train)=0.12
# End of epoch 08: err(train)=4.04 acc(train)=0.13
# End of epoch 09: err(train)=4.03 acc(train)=0.12
# End of epoch 10: err(train)=4.02 acc(train)=0.13
#                  err(valid)=3.98 acc(valid)=0.13
# End of epoch 11: err(train)=4.02 acc(train)=0.13
# End of epoch 12: err(train)=4.02 acc(train)=0.13
# End of epoch 13: err(train)=4.01 acc(train)=0.13
# End of epoch 14: err(train)=4.00 acc(train)=0.13
# End of epoch 15: err(train)=4.00 acc(train)=0.13
#                  err(valid)=3.97 acc(valid)=0.14
# End of epoch 16: err(train)=3.99 acc(train)=0.14
# End of epoch 17: err(train)=3.99 acc(train)=0.14
# End of epoch 18: err(train)=3.99 acc(train)=0.14
# End of epoch 19: err(train)=3.99 acc(train)=0.14
# End of epoch 20: err(train)=3.99 acc(train)=0.14
#                  err(valid)=3.95 acc(valid)=0.14
# End of epoch 21: err(train)=3.98 acc(train)=0.14
# End of epoch 22: err(train)=3.98 acc(train)=0.14
# End of epoch 23: err(train)=3.98 acc(train)=0.14
# End of epoch 24: err(train)=3.98 acc(train)=0.14
# End of epoch 25: err(train)=3.98 acc(train)=0.14
#                  err(valid)=3.99 acc(valid)=0.13
# End of epoch 26: err(train)=3.97 acc(train)=0.14
# End of epoch 27: err(train)=3.97 acc(train)=0.14
# End of epoch 28: err(train)=3.97 acc(train)=0.14
# End of epoch 29: err(train)=3.96 acc(train)=0.15
# End of epoch 30: err(train)=3.96 acc(train)=0.14
#                  err(valid)=4.01 acc(valid)=0.14
# End of epoch 31: err(train)=3.96 acc(train)=0.15
# End of epoch 32: err(train)=3.96 acc(train)=0.15
# End of epoch 33: err(train)=3.96 acc(train)=0.15
# End of epoch 34: err(train)=3.96 acc(train)=0.15
# End of epoch 35: err(train)=3.96 acc(train)=0.15
#                  err(valid)=3.93 acc(valid)=0.15
# End of epoch 36: err(train)=3.95 acc(train)=0.15
# End of epoch 37: err(train)=3.95 acc(train)=0.15
# End of epoch 38: err(train)=3.95 acc(train)=0.15
# End of epoch 39: err(train)=3.95 acc(train)=0.15
# End of epoch 40: err(train)=3.95 acc(train)=0.15
#                  err(valid)=3.93 acc(valid)=0.16
# End of epoch 41: err(train)=3.95 acc(train)=0.15
# End of epoch 42: err(train)=3.95 acc(train)=0.15
# End of epoch 43: err(train)=3.95 acc(train)=0.15
# End of epoch 44: err(train)=3.95 acc(train)=0.15
# End of epoch 45: err(train)=3.95 acc(train)=0.15
#                  err(valid)=3.93 acc(valid)=0.16
# End of epoch 46: err(train)=3.94 acc(train)=0.15
# End of epoch 47: err(train)=3.95 acc(train)=0.15
# End of epoch 48: err(train)=3.93 acc(train)=0.15
# End of epoch 49: err(train)=3.94 acc(train)=0.15
# End of epoch 50: err(train)=3.94 acc(train)=0.15
#                  err(valid)=3.98 acc(valid)=0.14
# End of epoch 51: err(train)=3.94 acc(train)=0.15
# End of epoch 52: err(train)=3.94 acc(train)=0.15
# End of epoch 53: err(train)=3.94 acc(train)=0.15
# End of epoch 54: err(train)=3.94 acc(train)=0.15
# End of epoch 55: err(train)=3.94 acc(train)=0.15
#                  err(valid)=3.96 acc(valid)=0.15
# End of epoch 56: err(train)=3.94 acc(train)=0.15
# End of epoch 57: err(train)=3.93 acc(train)=0.16
# End of epoch 58: err(train)=3.94 acc(train)=0.15
# End of epoch 59: err(train)=3.93 acc(train)=0.15
# End of epoch 60: err(train)=3.94 acc(train)=0.15
#                  err(valid)=3.93 acc(valid)=0.15
# End of epoch 61: err(train)=3.93 acc(train)=0.16
# End of epoch 62: err(train)=3.93 acc(train)=0.15
# End of epoch 63: err(train)=3.93 acc(train)=0.15
# End of epoch 64: err(train)=3.94 acc(train)=0.15
# End of epoch 65: err(train)=3.93 acc(train)=0.15
#                  err(valid)=3.90 acc(valid)=0.17
# End of epoch 66: err(train)=3.93 acc(train)=0.15
# End of epoch 67: err(train)=3.93 acc(train)=0.15
# End of epoch 68: err(train)=3.93 acc(train)=0.16
# End of epoch 69: err(train)=3.93 acc(train)=0.15
# End of epoch 70: err(train)=3.92 acc(train)=0.16
#                  err(valid)=3.96 acc(valid)=0.15
# End of epoch 71: err(train)=3.93 acc(train)=0.15
# End of epoch 72: err(train)=3.93 acc(train)=0.15
# End of epoch 73: err(train)=3.93 acc(train)=0.15
# End of epoch 74: err(train)=3.93 acc(train)=0.15
# End of epoch 75: err(train)=3.93 acc(train)=0.16
#                  err(valid)=3.93 acc(valid)=0.16
# End of epoch 76: err(train)=3.92 acc(train)=0.16
# End of epoch 77: err(train)=3.93 acc(train)=0.15
# End of epoch 78: err(train)=3.92 acc(train)=0.16
# End of epoch 79: err(train)=3.92 acc(train)=0.16
# End of epoch 80: err(train)=3.93 acc(train)=0.15
#                  err(valid)=3.93 acc(valid)=0.16
# End of epoch 81: err(train)=3.93 acc(train)=0.16
# End of epoch 82: err(train)=3.92 acc(train)=0.15
# End of epoch 83: err(train)=3.92 acc(train)=0.16
# End of epoch 84: err(train)=3.92 acc(train)=0.16
# End of epoch 85: err(train)=3.92 acc(train)=0.16
#                  err(valid)=3.91 acc(valid)=0.16
# End of epoch 86: err(train)=3.92 acc(train)=0.15
# End of epoch 87: err(train)=3.92 acc(train)=0.16
# End of epoch 88: err(train)=3.92 acc(train)=0.16
# End of epoch 89: err(train)=3.93 acc(train)=0.15
# End of epoch 90: err(train)=3.92 acc(train)=0.16
#                  err(valid)=3.91 acc(valid)=0.17
# End of epoch 91: err(train)=3.92 acc(train)=0.16
# End of epoch 92: err(train)=3.92 acc(train)=0.16
# End of epoch 93: err(train)=3.92 acc(train)=0.16
# End of epoch 94: err(train)=3.92 acc(train)=0.16
# End of epoch 95: err(train)=3.92 acc(train)=0.16
#                  err(valid)=3.91 acc(valid)=0.16
# End of epoch 96: err(train)=3.92 acc(train)=0.16
# End of epoch 97: err(train)=3.92 acc(train)=0.16
# End of epoch 98: err(train)=3.92 acc(train)=0.16
# End of epoch 99: err(train)=3.92 acc(train)=0.16
# End of epoch 100: err(train)=3.91 acc(train)=0.16
#                  err(valid)=3.91 acc(valid)=0.16
# Time taken: 14709.657924

# %%
#l2 Regularization beta = 0.001
#http://stackoverflow.com/questions/38286717/tensorflow-regularization-with-l2-loss-how-to-apply-to-all-weights-not-just
with graph_l2001.as_default():
    with tf.name_scope('data'):
        inputs = tf.placeholder(tf.float32, [None, train_data.inputs.shape[1]], 'inputs')
        targets = tf.placeholder(tf.float32, [None, train_data.num_classes], 'targets')
        num_hidden = 200
        beta = 0.001
    with tf.name_scope('fc-layer-3'):
        w1,hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], num_hidden)
        w2,hidden_2 = fully_connected_layer(hidden_1, num_hidden, num_hidden)
        w3,hidden_3 = fully_connected_layer(hidden_2, num_hidden, num_hidden)
    with tf.name_scope('output-layer'):
        w4,outputs = fully_connected_layer(hidden_3, num_hidden, train_data.num_classes, tf.identity)

    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets)) + tf.reduce_mean(beta*(tf.nn.l2_loss(w1)+tf.nn.l2_loss(w2)+tf.nn.l2_loss(w3)+tf.nn.l2_loss(w4)))
    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)),tf.float32))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer().minimize(error)
    init = tf.global_variables_initializer()
start = time.time()
err_l2001_train,acc_l2001_train,err_l2001_valid,acc_l2001_valid = run_graph(graph_l2001)
print("Time taken: %f"%(time.time()-start))
# Out:
# End of epoch 01: err(train)=2.18 acc(train)=0.32
# End of epoch 02: err(train)=1.86 acc(train)=0.39
# End of epoch 03: err(train)=1.77 acc(train)=0.41

# %%
f = open('./log_100/Regularization.csv', 'w' )
f.write( time.ctime(int(time.time()))+'\nLayers,'+'err_train,'+'acc_train,'+'err_valid,'+'acc_valid'+'\n'+
'l101,'+
repr(err_l101_train)+','+
repr(acc_l101_train)+','+
repr(err_l101_valid)+','+
repr(acc_l101_valid)+'\n'+
'l1001,'+
repr(err_l1001_train)+','+
repr(acc_l1001_train)+','+
repr(err_l1001_valid)+','+
repr(acc_l1001_valid)+'\n'+
'l201,'+
repr(err_l201_train)+','+
repr(acc_l201_train)+','+
repr(err_l201_valid)+','+
repr(acc_l201_valid)+'\n'+
'l2001,'+
repr(err_l2001_train)+','+
repr(acc_l2001_train)+','+
repr(err_l2001_valid)+','+
repr(acc_l2001_valid)+'\n')
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e4a1ba95ace0> in <module>()
#      20 repr(acc_l2001_train)+','+
#      21 repr(err_l2001_valid)+','+
# ---> 22 repr(acc_l2001_valid)+'\n')
#      23 f.close()
#
# NameError: name 'acc_l1001_train' is not defined

# %%
def plot_graph(err_train,acc_train,err_valid,acc_valid,name="Graph"):
    path='./graphs_100/'+name
    val_epoch=range(5,105,5)
    err_epoch=range(1,101,1)
    plt.grid()
    plt.plot(err_epoch,err_train,'-b+',label='Train Error')
    plt.plot(val_epoch,err_valid,'-ro',label='Validation Error')
    plt.xlabel('Epochs')
    plt.ylabel('Error')
    plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
    plt.savefig(path+'_error.png')
    #plt.show()
    plt.close()
    plt.grid()
    plt.plot(err_epoch,acc_train,'-b+',label='Train Accuracy')
    plt.plot(val_epoch,acc_valid,'-ro',label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
    plt.savefig(path+'_accuracy.png')
    #plt.show()
    plt.close()

# %%
plot_graph(err_l101_train,acc_l101_train,err_l101_valid,acc_l101_valid,'Regularization_l101')
#plot_graph(err_l1001_train,acc_l1001_train,err_l1001_valid,acc_l1001_valid,'Regularization_l1001')
plot_graph(err_l201_train,acc_l201_train,err_l201_valid,acc_l201_valid,'Regularization_l201')
#plot_graph(err_l2001_train,acc_l2001_train,err_l2001_valid,acc_l2001_valid,'Regularization_l2001')

# %%
print acc_five_layer_valid

# %% [markdown]
# ## End of Layer variation experiment
